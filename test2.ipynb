# %%
pip install -e .
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///C:/Users/157336/Python%20Scripts/Tdqeq
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# ...
#   Building editable for tdqeq (pyproject.toml): started
#   Building editable for tdqeq (pyproject.toml): finished with status 'done'
#   Created wheel for tdqeq: filename=tdqeq-0.1.0-0.editable-py3-none-any.whl size=5440 sha256=a6fb89f92ffee32dc76e5777f9c4c2a4c01f27bfbf3c3946f67f7dbea7b63080
# ...

# %%
from tdqeq.pipeline import Pipeline
import json

# %%
# 2. Build the Pipeline
pipeline = Pipeline(
    dpi=200,
    device='cpu',
    batch_size=10,
    mode='auto'
)
# Out:
# [INFO] 2026-07-20 23:42:55,683 [RapidTable] download_file.py:56: File exists and is valid: C:\Users\157336\AppData\Roaming\Python\Python311\site-packages\rapid_table\models\slanet-plus.onnx
# [INFO] 2026-07-20 23:42:55,684 [RapidTable] base.py:53: Using engine_name: onnxruntime
# [INFO] 2026-07-20 23:42:55,691 [RapidTable] main.py:35: Using C:\Users\157336\AppData\Roaming\Python\Python311\site-packages\rapid_table\models\slanet-plus.onnx
# [INFO] 2026-07-20 23:42:56,254 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# [INFO] 2026-07-20 23:42:56,266 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\157336\AppData\Roaming\Python\Python311\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-07-20 23:42:56,267 [RapidOCR] main.py:53: Using C:\Users\157336\AppData\Roaming\Python\Python311\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.onnx
# [INFO] 2026-07-20 23:42:56,465 [RapidOCR] base.py:22: Using engine_name: onnxruntime
# ...

# %%
pdf_path = r"C:/Users/157336/Downloads/CR_Series.pdf"
tables = pipeline.run(pdf_path, page_range=(2,2))
print(f"Extracted {len(tables)} tables!")
# Out:
# 2026-07-20 23:43:01.574 | INFO     | tdqeq.pipeline:run:169 -   Loaded 1 page(s)
# Detecting tables: 100%|██████████| 1/1 [00:03<00:00,  3.41s/it]
# 2026-07-20 23:43:05.084 | INFO     | tdqeq.pipeline:run:195 -   1 region(s) across 1 page(s) — running batch inference...
# BatchRec: 100%|██████████| 1/1 [00:23<00:00, 23.22s/it]
# 2026-07-20 23:43:28.353 | INFO     | tdqeq.pipeline:run:202 -   Extracted 1 table(s).
# Extracted 1 tables!

# %%
tables[0].cls_score
# Out:
# 0.941

# %% [markdown]
# '<html><body><table class="■ Standard Electrical Specifications"><tr><td>Item</td><td>Power Rating at 70 \uf0b0 C Jumper</td><td>Operating Temp. Range</td><td>Max. Operating Voltage</td><td>Max. Overload Voltage</td><td>Resistance</td><td>Range</td><td rowspan="2">TCR (PPM/ \uf0b0 C)</td></tr><tr><td>Type</td><td>Rated Current 1/32W</td><td>-55 ~ +125 \uf0b0 C</td><td>15V</td><td></td><td>±1%(E24 、 E96)</td><td>±5%(E24)</td></tr><tr><td rowspan="2">CR-E5 (01005)</td><td>Jumper: 0.5A</td><td rowspan="2"></td><td rowspan="2"></td><td rowspan="2">30V</td><td>10Ω -</td><td>- 1MΩ 0Ω (<50mΩ)</td><td>±300 -</td></tr><tr><td>1/20W</td><td></td><td></td><td></td></tr><tr><td rowspan="2">CR-01 (0201)</td><td>Jumper: 1A</td><td rowspan="2">-55 ~ +125 \uf0b0 C</td><td rowspan="2">25V</td><td rowspan="2">50V</td><td>1Ω - 10MΩ</td><td>0Ω (<50mΩ)</td><td>±200 -</td></tr><tr><td>1/16W</td><td>- 1Ω 10Ω</td><td>- 9.76Ω - 1MΩ</td><td>±200 ±100</td></tr><tr><td>CR-02 (0402)</td><td>Jumper: 1A</td><td rowspan="2">-55 ~ +155 \uf0b0 C</td><td rowspan="2">50V</td><td rowspan="2">100V</td><td>1.02MΩ 20.5MΩ - -</td><td>- 20MΩ 100MΩ 0Ω (<50mΩ)</td><td>±200 ±400</td></tr><tr><td>1/10W</td><td>-55 ~ +155 \uf0b0 C 75V</td><td>150V</td><td>1Ω - 9.76Ω 10Ω - 1MΩ</td><td>- ±200 ±100</td></tr><tr><td rowspan="2"></td><td>Jumper: 1A</td><td rowspan="2"></td><td rowspan="2"></td><td rowspan="2"></td><td>1.02MΩ - 20.5MΩ -</td><td>20MΩ 100MΩ</td><td>±200 ±400</td></tr><tr><td></td><td>- 1Ω -</td><td>0Ω (<50mΩ) 9.76Ω</td><td>- ±200</td></tr><tr><td rowspan="2">CR-05 (0805)</td><td>1/8W</td><td rowspan="2">-55 ~ +155 \uf0b0 C</td><td rowspan="2">150V</td><td rowspan="2">300V</td><td>10Ω - 1MΩ 1.02MΩ -</td><td>20MΩ</td><td>±100 ±200</td></tr><tr><td>Jumper: 2A</td><td>20.5MΩ - -</td><td>100MΩ 0Ω (<50mΩ)</td><td>±400 -</td></tr><tr><td rowspan="2">CR-06 (1206)</td><td>1/4W</td><td rowspan="2">-55 ~ +155 \uf0b0 C</td><td rowspan="2">200V</td><td rowspan="2">400V</td><td>1Ω - 9.76Ω 10Ω - 1MΩ</td><td></td><td>±200 ±100</td></tr><tr><td></td><td>1.02MΩ - 20.5MΩ -</td><td>20MΩ 100MΩ</td><td>±200 ±400</td></tr><tr><td rowspan="3">CR-10 (1210)</td><td>Jumper: 2A</td><td rowspan="2">-55 ~ +155 \uf0b0 C</td><td rowspan="2"></td><td rowspan="2"></td><td>-</td><td>0Ω (<50mΩ)</td><td>-</td></tr><tr><td>1/3W</td><td>1Ω - 10Ω - 1.02MΩ -</td><td>9.76Ω 1MΩ 20MΩ</td><td>±200 ±100 ±200</td></tr><tr><td>Jumper: 2.5A</td><td></td><td>200V</td><td>400V</td><td>20.5MΩ -</td><td>- 39MΩ 0Ω (<50mΩ)</td><td>±400 -</td></tr></table></body></html>'

# %% [markdown]
# '<html><body><table class="■ Standard Electrical Specifications"><tr><td rowspan="2">Item</td><td rowspan="2">Power Rating at 70 \uf0b0 C Jumper Rated Current</td><td rowspan="2">Operating Temp. Range</td><td rowspan="2">Max. Operating Voltage</td><td rowspan="2">Max. Overload Voltage</td><td colspan="2">Resistance Range</td><td rowspan="2">TCR (PPM/ \uf0b0 C)</td></tr><tr><td>±1%(E24 、 E96)</td><td>±5%(E24)</td></tr><tr><td rowspan="2">CR-E5 (01005)</td><td>1/32W</td><td rowspan="2">-55 ~ +125 \uf0b0 C</td><td rowspan="2">15V</td><td rowspan="2">30V</td><td colspan="2">10Ω - 1MΩ</td><td>±300</td></tr><tr><td>Jumper: 0.5A</td><td>-</td><td>0Ω (<50mΩ)</td><td>-</td></tr><tr><td rowspan="2">CR-01 (0201)</td><td>1/20W</td><td rowspan="2">-55 ~ +125 \uf0b0 C</td><td rowspan="2">25V</td><td rowspan="2">50V</td><td colspan="2">1Ω - 10MΩ</td><td>±200</td></tr><tr><td>Jumper: 1A</td><td>-</td><td>0Ω (<50mΩ)</td><td>-</td></tr><tr><td rowspan="2">CR-02 (0402)</td><td rowspan="2">1/16W</td><td rowspan="2">-55 ~ +155 \uf0b0 C</td><td rowspan="2">50V</td><td rowspan="2">100V</td><td colspan="2">1Ω - 9.76Ω 10Ω - 1MΩ 1.02MΩ - 20MΩ 20.5MΩ - 100MΩ</td><td>±200 ±100 ±200 ±400</td></tr><tr><td>Jumper: 1A</td><td>-</td><td>0Ω (<50mΩ)</td><td>-</td></tr><tr><td rowspan="2">CR-03 (0603)</td><td>1/10W</td><td rowspan="2">-55 ~ +155 \uf0b0 C</td><td rowspan="2">75V</td><td rowspan="2">150V</td><td colspan="2">1Ω - 9.76Ω 10Ω - 1MΩ 1.02MΩ - 20MΩ 20.5MΩ - 100MΩ</td><td>±200 ±100 ±200 ±400</td></tr><tr><td>Jumper: 1A</td><td>-</td><td>0Ω (<50mΩ)</td><td>-</td></tr><tr><td rowspan="2">CR-05 (0805)</td><td>1/8W</td><td rowspan="2">-55 ~ +155 \uf0b0 C</td><td rowspan="2">150V</td><td rowspan="2">300V</td><td colspan="2">1Ω - 9.76Ω 10Ω - 1MΩ 1.02MΩ - 20MΩ 20.5MΩ - 100MΩ</td><td>±200 ±100 ±200 ±400</td></tr><tr><td>Jumper: 2A</td><td>-</td><td>0Ω (<50mΩ)</td><td>-</td></tr><tr><td rowspan="2">CR-06 (1206)</td><td>1/4W</td><td rowspan="2">-55 ~ +155 \uf0b0 C</td><td rowspan="2">200V</td><td rowspan="2">400V</td><td colspan="2">1Ω - 9.76Ω 10Ω - 1MΩ 1.02MΩ - 20MΩ 20.5MΩ - 100MΩ</td><td>±200 ±100 ±200 ±400</td></tr><tr><td>Jumper: 2A</td><td>-</td><td>0Ω (<50mΩ)</td><td>-</td></tr><tr><td rowspan="2">CR-10 (1210)</td><td>1/3W</td><td rowspan="2">-55 ~ +155 \uf0b0 C</td><td rowspan="2">200V</td><td rowspan="2">400V</td><td colspan="2">1Ω - 9.76Ω 10Ω - 1MΩ 1.02MΩ - 20MΩ 20.5MΩ - 39MΩ</td><td>±200 ±100 ±200 ±400</td></tr><tr><td>Jumper: 2.5A</td><td>-</td><td>0Ω (<50mΩ)</td><td>-</td></tr></table></body></html>'

# %% [markdown]
# "<html><body><table><tr><td colspan=\"3\">PIN DESCRIPTION</td></tr><tr><td>PIN NUMBER</td><td>SYMBOL</td><td>DESCRIPTION</td></tr><tr><td>1, 2, 22, 26</td><td>V IN</td><td>Input voltage</td></tr><tr><td>3, 4, 13, 27</td><td>P GND</td><td>Power signal return ground</td></tr><tr><td>5 to 9</td><td>SW</td><td>Switching node signal; output inductor connection point</td></tr><tr><td>10, 11, 28</td><td>GL</td><td>Low side power MOSFET gate signal</td></tr><tr><td>12</td><td>V DRV</td><td>Supply voltage for internal gate driver. Connect a 2.2 μF decoupling capacitor to P GND</td></tr><tr><td>14</td><td>P GOOD</td><td>Power good signal output; open drain</td></tr><tr><td>15</td><td>V DD</td><td>Supply voltage for internal logic. Connect a 1 μF decoupling capacitor to A GND</td></tr><tr><td>16, 25</td><td>A GND</td><td>Analog signal return ground</td></tr><tr><td>17</td><td>FB</td><td>Output voltage feedback pin; connect to V OUT through a resistor divider network.</td></tr><tr><td>18</td><td>V OUT</td><td>Output voltage sense pin</td></tr><tr><td>19</td><td>EN</td><td>Enable pin</td></tr><tr><td>20</td><td>MODE2</td><td>Soft start and current limit selection; connect a resistor to V DD or A GND per Table 2</td></tr><tr><td>21</td><td>MODE1</td><td>Operating mode and switching frequency selection; connect a resistor to V DD or A GND per Table 1</td></tr><tr><td>23</td><td>BOOT</td><td>Bootstrap pin; connect a capacitor to PHASE pin for HS power MOSFET gate voltage supply</td></tr><tr><td>24</td><td>PHASE</td><td>Switching node signal for bootstrap return path</td></tr></table></body></html>",

# %% [markdown]
# "<html><body><table><tr><td colspan=\"3\">PIN DESCRIPTION</td></tr><tr><td>PIN NUMBER</td><td>SYMBOL</td><td>DESCRIPTION</td></tr><tr><td>1, 2, 22, 26</td><td>V IN</td><td>Input voltage</td></tr><tr><td>3, 4, 13, 27</td><td>P GND</td><td>Power signal return ground</td></tr><tr><td>5 to 9</td><td>SW</td><td>Switching node signal; output inductor connection point</td></tr><tr><td>10, 11, 28</td><td>GL</td><td>Low side power MOSFET gate signal</td></tr><tr><td>12</td><td>V DRV</td><td>Supply voltage for internal gate driver. Connect a 2.2 \u03bcF decoupling capacitor to P GND</td></tr><tr><td>14</td><td>P GOOD</td><td>Power good signal output; open drain</td></tr><tr><td>15</td><td>V DD</td><td>Supply voltage for internal logic. Connect a 1 \u03bcF decoupling capacitor to A GND</td></tr><tr><td>16, 25</td><td>A GND</td><td>Analog signal return ground</td></tr><tr><td>17</td><td>FB</td><td>Output voltage feedback pin; connect to V OUT through a resistor divider network.</td></tr><tr><td>18</td><td>V OUT</td><td>Output voltage sense pin</td></tr><tr><td>19</td><td>EN</td><td>Enable pin</td></tr><tr><td>20</td><td>MODE2</td><td>Soft start and current limit selection; connect a resistor to V DD or A GND per Table 2</td></tr><tr><td>21 23</td><td>MODE1</td><td>Operating mode and switching frequency selection; connect a resistor to V DD or A GND per Table 1</td></tr><tr><td>24</td><td>BOOT</td><td>Bootstrap pin; connect a capacitor to PHASE pin for HS power MOSFET gate voltage supply</td></tr><tr><td></td><td>PHASE</td><td>Switching node signal for bootstrap return path</td></tr></table></body></html>",

# %% [markdown]
# <html><body><table class=\"Vishay Siliconix\"><tr><td colspan=\"4\">ABSOLUTE MAXIMUM RATINGS (T A = 25 \u00b0C, unless otherwise noted)</td></tr><tr><td>ELECTRICAL PARAMETER</td><td>CONDITIONS</td><td>LIMITS</td><td>UNIT</td></tr><tr><td>V IN</td><td>Reference to P GND</td><td>-0.3 to +25</td><td rowspan=\"8\">V</td></tr><tr><td>V OUT</td><td>Reference to P GND</td><td>-0.3 to +22</td></tr><tr><td>V DD / V DRV</td><td>Reference to P GND</td><td>-0.3 to +6</td></tr><tr><td>SW / PHASE</td><td>Reference to P GND</td><td>-0.3 to +25</td></tr><tr><td>SW / PHASE (AC)</td><td>100 ns; reference to P GND</td><td>-8 to +30</td></tr><tr><td>BOOT</td><td>Reference to P GND</td><td>-0.3 to +31</td></tr><tr><td>BOOT to SW</td><td></td><td>-0.3 to +6</td></tr><tr><td>A GND to P GND</td><td></td><td>-0.3 to +0.3</td></tr><tr><td>EN</td><td>Reference to A GND</td><td>-0.3 to +25</td></tr><tr><td>All other pins</td><td>Reference to A GND</td><td>-0.3 to +6</td></tr><tr><td colspan=\"3\">Temperature</td><td rowspan=\"3\">\u00b0C</td></tr><tr><td>Junction temperature</td><td>T J</td><td>-40 to +150</td></tr><tr><td>Storage temperature</td><td>T</td><td>-65 to +150</td></tr><tr><td colspan=\"4\">STG</td></tr><tr><td>Power Dissipation</td><td></td><td>16</td><td rowspan=\"2\">\u00b0C/W</td></tr><tr><td>Junction-to-ambient thermal impedance (R \uf071 JA ) Junction-to-case thermal impedance (R )</td><td></td><td>2</td></tr><tr><td>\uf071 JC</td><td>Ambient temperature = 25 \u00b0C</td><td></td><td rowspan=\"2\">W</td></tr><tr><td>Maximum power dissipation ESD Protection</td><td></td><td>7.75</td></tr><tr><td colspan=\"6\"></td></tr><tr><td rowspan=\"2\">Electrostatic discharge protection</td><td>Human body model</td><td>4000</td><td rowspan=\"2\">V</td></tr><tr><td>Charged device model</td><td>1000</td><td></td></tr></table></body></html>",

# %% [markdown]
# <html><body><table class=\"Vishay Siliconix\"><tr><td colspan=\"4\">ABSOLUTE MAXIMUM RATINGS (T A = 25 °C, unless otherwise noted)</td></tr><tr><td>ELECTRICAL PARAMETER</td><td>CONDITIONS</td><td>LIMITS</td><td>UNIT</td></tr><tr><td>V IN</td><td>Reference to P GND</td><td>-0.3 to +25</td><td rowspan=\"10\">V</td></tr><tr><td>V OUT</td><td>Reference to P GND</td><td>-0.3 to +22</td></tr><tr><td>V DD / V DRV</td><td>Reference to P GND</td><td>-0.3 to +6</td></tr><tr><td>SW / PHASE</td><td>Reference to P GND</td><td>-0.3 to +25</td></tr><tr><td>SW / PHASE (AC)</td><td>100 ns; reference to P GND</td><td>-8 to +30</td></tr><tr><td>BOOT</td><td>Reference to P GND</td><td>-0.3 to +31</td></tr><tr><td>BOOT to SW</td><td></td><td>-0.3 to +6</td></tr><tr><td>A GND to P GND</td><td></td><td>-0.3 to +0.3</td></tr><tr><td>EN</td><td>Reference to A GND</td><td>-0.3 to +25</td></tr><tr><td>All other pins</td><td>Reference to A GND</td><td>-0.3 to +6</td></tr><tr><td colspan=\"4\">Temperature</td></tr><tr><td>Junction temperature</td><td>T J</td><td>-40 to +150</td><td rowspan=\"2\">°C</td></tr><tr><td>Storage temperature</td><td>T STG</td><td>-65 to +150</td></tr><tr><td colspan=\"4\">Power Dissipation</td></tr><tr><td>Junction-to-ambient thermal impedance (R  JA )</td><td></td><td>16</td><td rowspan=\"2\">°C/W</td></tr><tr><td>Junction-to-case thermal impedance (R  JC )</td><td></td><td>2</td></tr><tr><td>Maximum power dissipation</td><td>Ambient temperature = 25 °C</td><td>7.75</td><td>W</td></tr><tr><td colspan=\"4\">ESD Protection</td></tr><tr><td rowspan=\"2\">Electrostatic discharge protection</td><td>Human body model</td><td>4000</td><td rowspan=\"2\">V</td></tr><tr><td>Charged device model</td><td>1000</td></tr></table></body></html>",
